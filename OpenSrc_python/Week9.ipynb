# %%
print("201911155 김미승")
# Out:
# 201911155 김미승

# %%
x=int(input("Enter x : "))
y = 3*x*x+5*x+3
print("2차 방정식 y 값 : ",y)
# Out:
# Enter x : 5
# 2차 방정식 y 값 :  103

# %%
x = int(input("반지름을 입력하세요. : "))
pi = 3.14
length = 2 * pi * x
size = pi * x * x
str = "원의 둘레 : {0:.3f} \n원의 넓이 : {1:.3f}".format(length,size)
print(str)
# Out:
# 반지름을 입력하세요. : 10
# 원의 둘레 : 62.800
# 원의 넓이 : 314.000
